# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
found_cities = []
city_name = []
city_cloudiness = []
city_country = []
city_date = []
city_humidity = []
city_Lat = []
city_Lng = []
city_Max_Temp = []
city_wind_speed = []

city_index = 0
set_index = 1

params = {"units" : "Imperial"}

print("Beginning Data Retrieval\n-----------------------------")

for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    
    try:
        weather_data = requests.get(query_url, params = params).json()
        
        city_name.append(weather_data['name'])
        city_cloudiness.append(weather_data['clouds']['all'])
        city_country.append(weather_data['sys']['country'])
        city_date.append(weather_data['dt'])
        city_humidity.append(weather_data['main']['humidity'])
        city_Lat.append(weather_data['coord']['lat'])
        city_Lng.append(weather_data['coord']['lon'])
        city_Max_Temp.append(weather_data['main']['temp_max'])
        city_wind_speed.append(weather_data['wind']['speed'])
        
        city_index += 1
        
        if city_index == 50:
            set_index += 1
            city_index = 0
            print(f"Processing Record {city_index} of Set {set_index} | {city}")
            
        else:
            print(f"Processing Record {city_index} of Set {set_index} | {city}")
    
    except KeyError:
        print("City not found. Skipping...")
        
print("-----------------------------\nData Retrieval Complete\n-----------------------------")
        
found_cities = zip(city_name, city_cloudiness, city_country, city_date, city_humidity, city_Lat, city_Lng, city_Max_Temp, city_wind_speed)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | kungurtug
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | gizo
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | caravelas
# Processing Record 10 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 11 of Set 1 | jalu
# Processing Record 12 of Set 1 | montenegro
# City not found. Skipping...
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | maldonado
# City not found. Skipping...
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | khotynets
# City not found. Skipping...
# Processing Record 22 of Set 1 | kavieng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 1 | vila franca do campo
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | karpogory
# Processing Record 27 of Set 1 | lahij
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | hithadhoo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 32 of Set 1 | san patricio
# City not found. Skipping...
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | rawson
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | oshnaviyeh
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | islamkot
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | vostok
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | port hedland
# Processing Record 48 of Set 1 | kirakira
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 0 of Set 2 | nanortalik
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | burnie
# Processing Record 4 of Set 2 | preston
# City not found. Skipping...
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | comodoro rivadavia
# Processing Record 7 of Set 2 | baoshan
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | madison
# Processing Record 11 of Set 2 | raudeberg
# Processing Record 12 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 13 of Set 2 | ketchikan
# Processing Record 14 of Set 2 | mantua
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | los llanos de aridane
# Processing Record 17 of Set 2 | terrace bay
# Processing Record 18 of Set 2 | saint anthony
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | sarankhola
# Processing Record 22 of Set 2 | avera
# City not found. Skipping...
# Processing Record 23 of Set 2 | khandyga
# Processing Record 24 of Set 2 | seminole
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | shelburne
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | joshimath
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | necochea
# Processing Record 34 of Set 2 | taunggyi
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | amazar
# Processing Record 37 of Set 2 | hamilton
# Processing Record 38 of Set 2 | biltine
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | santa fe
# Processing Record 41 of Set 2 | te anau
# Processing Record 42 of Set 2 | kenai
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | zeulenroda
# City not found. Skipping...
# Processing Record 45 of Set 2 | seguela
# City not found. Skipping...
# Processing Record 46 of Set 2 | nome
# Processing Record 47 of Set 2 | portland
# Processing Record 48 of Set 2 | taltal
# City not found. Skipping...
# Processing Record 49 of Set 2 | santa cruz de la palma
# Processing Record 0 of Set 3 | starnberg
# City not found. Skipping...
# Processing Record 1 of Set 3 | qarqin
# Processing Record 2 of Set 3 | arraial do cabo
# City not found. Skipping...
# Processing Record 3 of Set 3 | beroroha
# Processing Record 4 of Set 3 | klungkung
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | san marcos
# Processing Record 7 of Set 3 | sambava
# Processing Record 8 of Set 3 | hambantota
# Processing Record 9 of Set 3 | anuradhapura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 3 | aykhal
# Processing Record 11 of Set 3 | fairbanks
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | kastamonu
# Processing Record 14 of Set 3 | hermanus
# City not found. Skipping...
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | beloha
# Processing Record 17 of Set 3 | ardatov
# City not found. Skipping...
# Processing Record 18 of Set 3 | coquimbo
# Processing Record 19 of Set 3 | talnakh
# City not found. Skipping...
# Processing Record 20 of Set 3 | provideniya
# City not found. Skipping...
# Processing Record 21 of Set 3 | pathein
# Processing Record 22 of Set 3 | angola
# Processing Record 23 of Set 3 | aginskoye
# Processing Record 24 of Set 3 | san angelo
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | richards bay
# City not found. Skipping...
# Processing Record 28 of Set 3 | moussoro
# City not found. Skipping...
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | mayumba
# Processing Record 32 of Set 3 | kunashak
# Processing Record 33 of Set 3 | gwadar
# Processing Record 34 of Set 3 | requena
# City not found. Skipping...
# Processing Record 35 of Set 3 | newport
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | cotonou
# Processing Record 38 of Set 3 | gloversville
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | zapolyarnyy
# City not found. Skipping...
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | mount gambier
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | darnah
# Processing Record 45 of Set 3 | okhtyrka
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | lesozavodsk
# Processing Record 49 of Set 3 | aksarka
# Processing Record 0 of Set 4 | ocos
# Processing Record 1 of Set 4 | yamada
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | banda aceh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 4 | cap malheureux
# Processing Record 6 of Set 4 | cubuk
# Processing Record 7 of Set 4 | airai
# Processing Record 8 of Set 4 | auki
# Processing Record 9 of Set 4 | roebourne
# Processing Record 10 of Set 4 | margate
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | jacareacanga
# Processing Record 13 of Set 4 | zhezkazgan
# Processing Record 14 of Set 4 | allende
# Processing Record 15 of Set 4 | saint-georges
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | lanzhou
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | otofuke
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | saravan
# Processing Record 24 of Set 4 | sindou
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | pacific grove
# Processing Record 27 of Set 4 | panzhihua
# City not found. Skipping...
# Processing Record 28 of Set 4 | kangaatsiaq
# Processing Record 29 of Set 4 | atambua
# Processing Record 30 of Set 4 | panorama
# Processing Record 31 of Set 4 | alyangula
# Processing Record 32 of Set 4 | maceio
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | kyshtovka
# Processing Record 38 of Set 4 | cayenne
# Processing Record 39 of Set 4 | catalina foothills
# Processing Record 40 of Set 4 | westport
# City not found. Skipping...
# Processing Record 41 of Set 4 | brae
# City not found. Skipping...
# Processing Record 42 of Set 4 | perth
# Processing Record 43 of Set 4 | yangzhou
# Processing Record 44 of Set 4 | camacha
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | hlukhiv
# Processing Record 47 of Set 4 | rockport
# Processing Record 48 of Set 4 | mana
# Processing Record 49 of Set 4 | kitami
# Processing Record 0 of Set 5 | bonavista
# Processing Record 1 of Set 5 | mogadishu
# Processing Record 2 of Set 5 | davao
# Processing Record 3 of Set 5 | changji
# Processing Record 4 of Set 5 | padang
# Processing Record 5 of Set 5 | lebu
# City not found. Skipping...
# Processing Record 6 of Set 5 | srednekolymsk
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | amahai
# Processing Record 9 of Set 5 | moindou
# Processing Record 10 of Set 5 | vao
# City not found. Skipping...
# Processing Record 11 of Set 5 | yar-sale
# Processing Record 12 of Set 5 | ilovlya
# Processing Record 13 of Set 5 | jinchang
# Processing Record 14 of Set 5 | camabatela
# Processing Record 15 of Set 5 | port alfred
# Processing Record 16 of Set 5 | zhigansk
# Processing Record 17 of Set 5 | porto novo
# Processing Record 18 of Set 5 | denpasar
# Processing Record 19 of Set 5 | prince rupert
# Processing Record 20 of Set 5 | porto belo
# Processing Record 21 of Set 5 | manta
# Processing Record 22 of Set 5 | kapaa
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | luanda
# City not found. Skipping...
# Processing Record 25 of Set 5 | poum
# City not found. Skipping...
# Processing Record 26 of Set 5 | mnogovershinnyy
# Processing Record 27 of Set 5 | meulaboh
# Processing Record 28 of Set 5 | mandalgovi
# Processing Record 29 of Set 5 | puerto escondido
# Processing Record 30 of Set 5 | haines junction
# Processing Record 31 of Set 5 | dodge city
# City not found. Skipping...
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | birin
# Processing Record 34 of Set 5 | araouane
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | umm lajj
# Processing Record 38 of Set 5 | kruisfontein
# Processing Record 39 of Set 5 | kysyl-syr
# Processing Record 40 of Set 5 | whyalla
# Processing Record 41 of Set 5 | gornopravdinsk
# Processing Record 42 of Set 5 | mundo nuevo
# Processing Record 43 of Set 5 | kamenka
# Processing Record 44 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 5 | san cristobal
# City not found. Skipping...
# Processing Record 46 of Set 5 | palafrugell
# City not found. Skipping...
# Processing Record 47 of Set 5 | george town
# City not found. Skipping...
# Processing Record 48 of Set 5 | alto piquiri
# Processing Record 49 of Set 5 | miquelon
# Processing Record 0 of Set 6 | burgeo
# Processing Record 1 of Set 6 | nakhon thai
# City not found. Skipping...
# Processing Record 2 of Set 6 | ancud
# Processing Record 3 of Set 6 | yarega
# Processing Record 4 of Set 6 | lahaina
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | sur
# Processing Record 7 of Set 6 | hami
# Processing Record 8 of Set 6 | shahrud
# Processing Record 9 of Set 6 | yinchuan
# City not found. Skipping...
# Processing Record 10 of Set 6 | kardailovo
# Processing Record 11 of Set 6 | fort-shevchenko
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | ban nahin
# Processing Record 14 of Set 6 | dunedin
# Processing Record 15 of Set 6 | inuvik
# Processing Record 16 of Set 6 | metsavan
# Processing Record 17 of Set 6 | stavern
# Processing Record 18 of Set 6 | hay river
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | abbeville
# Processing Record 22 of Set 6 | longyearbyen
# City not found. Skipping...
# Processing Record 23 of Set 6 | spencer
# Processing Record 24 of Set 6 | coihaique
# Processing Record 25 of Set 6 | kodinsk
# Processing Record 26 of Set 6 | dondo
# Processing Record 27 of Set 6 | atocha
# Processing Record 28 of Set 6 | dalhousie
# Processing Record 29 of Set 6 | bintulu
# Processing Record 30 of Set 6 | altamont
# Processing Record 31 of Set 6 | bethel
# Processing Record 32 of Set 6 | bela
# City not found. Skipping...
# Processing Record 33 of Set 6 | davidson
# Processing Record 34 of Set 6 | leh
# Processing Record 35 of Set 6 | vestmannaeyjar
# Processing Record 36 of Set 6 | komsomolskiy
# Processing Record 37 of Set 6 | santa quiteria
# City not found. Skipping...
# Processing Record 38 of Set 6 | sarany
# Processing Record 39 of Set 6 | hobo
# Processing Record 40 of Set 6 | galle
# Processing Record 41 of Set 6 | broken hill
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | uspenka
# Processing Record 44 of Set 6 | yeppoon
# Processing Record 45 of Set 6 | cienfuegos
# Processing Record 46 of Set 6 | maragogi
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | bilibino
# Processing Record 49 of Set 6 | nalut
# City not found. Skipping...
# Processing Record 0 of Set 7 | nenjiang
# Processing Record 1 of Set 7 | tiarei
# Processing Record 2 of Set 7 | zorritos
# City not found. Skipping...
# Processing Record 3 of Set 7 | lumberton
# Processing Record 4 of Set 7 | rocha
# Processing Record 5 of Set 7 | thompson
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | san quintin
# Processing Record 8 of Set 7 | sola
# Processing Record 9 of Set 7 | thinadhoo
# Processing Record 10 of Set 7 | mahibadhoo
# Processing Record 11 of Set 7 | katsuura
# Processing Record 12 of Set 7 | kaduy
# City not found. Skipping...
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | salinas
# Processing Record 16 of Set 7 | parana
# Processing Record 17 of Set 7 | quatre cocos
# Processing Record 18 of Set 7 | san borja
# Processing Record 19 of Set 7 | libertador general san martin
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | bahia blanca
# Processing Record 22 of Set 7 | zyryanka
# City not found. Skipping...
# Processing Record 23 of Set 7 | kogon
# Processing Record 24 of Set 7 | kautokeino
# Processing Record 25 of Set 7 | savalou
# Processing Record 26 of Set 7 | valparaiso
# Processing Record 27 of Set 7 | lishui
# Processing Record 28 of Set 7 | la rioja
# Processing Record 29 of Set 7 | takoradi
# Processing Record 30 of Set 7 | satipo
# Processing Record 31 of Set 7 | abu samrah
# Processing Record 32 of Set 7 | carlos chagas
# Processing Record 33 of Set 7 | marion
# Processing Record 34 of Set 7 | alamos
# Processing Record 35 of Set 7 | cabedelo
# Processing Record 36 of Set 7 | vanimo
# Processing Record 37 of Set 7 | xichang
# Processing Record 38 of Set 7 | praxedis guerrero
# Processing Record 39 of Set 7 | yafran
# Processing Record 40 of Set 7 | sorrento
# Processing Record 41 of Set 7 | vestmanna
# Processing Record 42 of Set 7 | antofagasta
# Processing Record 43 of Set 7 | tazovskiy
# Processing Record 44 of Set 7 | fort saint james
# Processing Record 45 of Set 7 | waingapu
# Processing Record 46 of Set 7 | deputatskiy
# Processing Record 47 of Set 7 | ardalstangen
# Processing Record 48 of Set 7 | qaqortoq
# Processing Record 49 of Set 7 | tasiilaq
# Processing Record 0 of Set 8 | bluefield
# Processing Record 1 of Set 8 | souillac
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | pimentel
# Processing Record 4 of Set 8 | caracuaro
# Processing Record 5 of Set 8 | yarmouth
# Processing Record 6 of Set 8 | borogontsy
# Processing Record 7 of Set 8 | kralendijk
# Processing Record 8 of Set 8 | atar
# Processing Record 9 of Set 8 | ughelli
# Processing Record 10 of Set 8 | gisborne
# Processing Record 11 of Set 8 | walvis bay
# Processing Record 12 of Set 8 | iracoubo
# Processing Record 13 of Set 8 | itarema
# Processing Record 14 of Set 8 | revelstoke
# Processing Record 15 of Set 8 | novikovo
# Processing Record 16 of Set 8 | naze
# Processing Record 17 of Set 8 | touros
# Processing Record 18 of Set 8 | aktau
# Processing Record 19 of Set 8 | ambilobe
# Processing Record 20 of Set 8 | fort nelson
# Processing Record 21 of Set 8 | luangwa
# Processing Record 22 of Set 8 | vitry-le-francois
# Processing Record 23 of Set 8 | sorong
# Processing Record 24 of Set 8 | san rafael
# Processing Record 25 of Set 8 | nizhniy kuranakh
# Processing Record 26 of Set 8 | teguldet
# Processing Record 27 of Set 8 | anloga
# Processing Record 28 of Set 8 | carutapera
# Processing Record 29 of Set 8 | minna
# Processing Record 30 of Set 8 | paamiut
# Processing Record 31 of Set 8 | palmer
# Processing Record 32 of Set 8 | navalmoral de la mata
# Processing Record 33 of Set 8 | soyo
# Processing Record 34 of Set 8 | kihei
# Processing Record 35 of Set 8 | baijiantan
# Processing Record 36 of Set 8 | mount isa
# Processing Record 37 of Set 8 | iquique
# Processing Record 38 of Set 8 | maunabo
# Processing Record 39 of Set 8 | grindavik
# Processing Record 40 of Set 8 | asyut
# Processing Record 41 of Set 8 | okhotsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 8 | xai-xai
# Processing Record 43 of Set 8 | kenora
# Processing Record 44 of Set 8 | san carlos de bariloche
# Processing Record 45 of Set 8 | razole
# Processing Record 46 of Set 8 | chapais
# Processing Record 47 of Set 8 | nantucket
# Processing Record 48 of Set 8 | guasdualito
# Processing Record 49 of Set 8 | vitim
# Processing Record 0 of Set 9 | doha
# Processing Record 1 of Set 9 | kaeo
# Processing Record 2 of Set 9 | buala
# Processing Record 3 of Set 9 | guarapuava
# Processing Record 4 of Set 9 | piacabucu
# Processing Record 5 of Set 9 | general roca
# Processing Record 6 of Set 9 | kefalos
# City not found. Skipping...
# Processing Record 7 of Set 9 | sibolga
# City not found. Skipping...
# Processing Record 8 of Set 9 | novobelokatay
# Processing Record 9 of Set 9 | luderitz
# Processing Record 10 of Set 9 | tobermory
# Processing Record 11 of Set 9 | skibbereen
# Processing Record 12 of Set 9 | carahue
# City not found. Skipping...
# Processing Record 13 of Set 9 | christchurch
# Processing Record 14 of Set 9 | ranau
# Processing Record 15 of Set 9 | smithers
# Processing Record 16 of Set 9 | loyga
# Processing Record 17 of Set 9 | biloela
# Processing Record 18 of Set 9 | susanville
# Processing Record 19 of Set 9 | tsiroanomandidy
# Processing Record 20 of Set 9 | keta
# Processing Record 21 of Set 9 | nieuw amsterdam
# City not found. Skipping...
# Processing Record 22 of Set 9 | port augusta
# Processing Record 23 of Set 9 | mayo
# Processing Record 24 of Set 9 | adrar
# Processing Record 25 of Set 9 | ingham
# Processing Record 26 of Set 9 | saint-francois
# Processing Record 27 of Set 9 | qasigiannguit
# Processing Record 28 of Set 9 | faanui
# Processing Record 29 of Set 9 | launceston
# Processing Record 30 of Set 9 | aguimes
# Processing Record 31 of Set 9 | cowra
# Processing Record 32 of Set 9 | ewa beach
# Processing Record 33 of Set 9 | cepu
# Processing Record 34 of Set 9 | garden city
# Processing Record 35 of Set 9 | kokopo
# Processing Record 36 of Set 9 | quime
# Processing Record 37 of Set 9 | bilma
# Processing Record 38 of Set 9 | charters towers
# Processing Record 39 of Set 9 | senno
# Processing Record 40 of Set 9 | axim
# Processing Record 41 of Set 9 | sakaiminato
# Processing Record 42 of Set 9 | staryy nadym
# Processing Record 43 of Set 9 | bayir
# Processing Record 44 of Set 9 | altagracia de orituco
# Processing Record 45 of Set 9 | oksfjord
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | sinop
# Processing Record 48 of Set 9 | altay
# Processing Record 49 of Set 9 | harper
# Processing Record 0 of Set 10 | shingu
# Processing Record 1 of Set 10 | shimoda
# Processing Record 2 of Set 10 | dalupaon
# Processing Record 3 of Set 10 | ust-omchug
# Processing Record 4 of Set 10 | ibitinga
# Processing Record 5 of Set 10 | conway
# Processing Record 6 of Set 10 | samarai
# Processing Record 7 of Set 10 | port-gentil
# Processing Record 8 of Set 10 | calama
# Processing Record 9 of Set 10 | kargasok
# Processing Record 10 of Set 10 | winston-salem
# Processing Record 11 of Set 10 | okha
# Processing Record 12 of Set 10 | constitucion
# Processing Record 13 of Set 10 | umea
# Processing Record 14 of Set 10 | port blair
# Processing Record 15 of Set 10 | rawlins
# Processing Record 16 of Set 10 | iberia
# Processing Record 17 of Set 10 | fukue
# Processing Record 18 of Set 10 | moerai
# Processing Record 19 of Set 10 | srikakulam
# Processing Record 20 of Set 10 | ritchie
# Processing Record 21 of Set 10 | uyuni
# Processing Record 22 of Set 10 | pryluky
# Processing Record 23 of Set 10 | norden
# Processing Record 24 of Set 10 | luwuk
# Processing Record 25 of Set 10 | at-bashi
# Processing Record 26 of Set 10 | boende
# Processing Record 27 of Set 10 | tondano
# Processing Record 28 of Set 10 | ternate
# Processing Record 29 of Set 10 | buta
# Processing Record 30 of Set 10 | elbistan
# Processing Record 31 of Set 10 | solnechnyy
# Processing Record 32 of Set 10 | byron bay
# Processing Record 33 of Set 10 | saint-joseph
# Processing Record 34 of Set 10 | mount barker
# Processing Record 35 of Set 10 | methoni
# Processing Record 36 of Set 10 | oussouye
# Processing Record 37 of Set 10 | half moon bay
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | ust-kuyga
# Processing Record 40 of Set 10 | peterhead
# Processing Record 41 of Set 10 | sabha
# Processing Record 42 of Set 10 | meadow lake
# Processing Record 43 of Set 10 | ust-kut
# Processing Record 44 of Set 10 | vardo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 10 | ukiah
# Processing Record 46 of Set 10 | yucca valley
# City not found. Skipping...
# Processing Record 47 of Set 10 | ostroleka
# Processing Record 48 of Set 10 | tautira
# Processing Record 49 of Set 10 | fallon
# Processing Record 0 of Set 11 | kindberg
# Processing Record 1 of Set 11 | sao joao da barra
# Processing Record 2 of Set 11 | gull lake
# Processing Record 3 of Set 11 | north bend
# Processing Record 4 of Set 11 | heihe
# Processing Record 5 of Set 11 | mosetse
# Processing Record 6 of Set 11 | bucksport
# Processing Record 7 of Set 11 | balclutha
# Processing Record 8 of Set 11 | lidkoping
# Processing Record 9 of Set 11 | north battleford
# Processing Record 10 of Set 11 | champerico
# Processing Record 11 of Set 11 | khanpur
# Processing Record 12 of Set 11 | kaitangata
# Processing Record 13 of Set 11 | hualmay
# Processing Record 14 of Set 11 | price
# Processing Record 15 of Set 11 | skjervoy
# Processing Record 16 of Set 11 | sebeta
# Processing Record 17 of Set 11 | nishihara
# Processing Record 18 of Set 11 | bagdarin
# Processing Record 19 of Set 11 | pauini
# Processing Record 20 of Set 11 | oneonta
# Processing Record 21 of Set 11 | ironton
# Processing Record 22 of Set 11 | channel-port aux basques
# Processing Record 23 of Set 11 | sisimiut
# City not found. Skipping...
# Processing Record 24 of Set 11 | alice
# City not found. Skipping...
# Processing Record 25 of Set 11 | billings
# Processing Record 26 of Set 11 | fairfield
# Processing Record 27 of Set 11 | saint-louis
# Processing Record 28 of Set 11 | severomuysk
# City not found. Skipping...
# Processing Record 29 of Set 11 | acapulco
# Processing Record 30 of Set 11 | emerald
# City not found. Skipping...
# Processing Record 31 of Set 11 | balabac
# Processing Record 32 of Set 11 | wittmund
# Processing Record 33 of Set 11 | marsaxlokk
# Processing Record 34 of Set 11 | riyadh
# Processing Record 35 of Set 11 | wisconsin rapids
# Processing Record 36 of Set 11 | hailun
# Processing Record 37 of Set 11 | kavaratti
# Processing Record 38 of Set 11 | yining
# Processing Record 39 of Set 11 | saint-pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# with open("cities.csv", mode='w') as csv_file:
#     city_writer = csv.writer(csv_file, delimiter=',')
    
#     city_writer.writerow(["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"])
#     for cities in found_cities:
#         city_writer.writerow(list(cities))

# %%
city_df = pd.DataFrame({
    "City" : city_name,
    "Cloudiness" : city_cloudiness,
    "Country" : city_country,
    "Date" : city_date,
    "Humidity" : city_humidity,
    "Lat" : city_Lat,
    "Lng" : city_Lng,
    "Max Temp" : city_Max_Temp,
    "Wind Speed" : city_wind_speed
})

city_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  Saint George           0      GR  1550688600        70  39.45  22.34
# 1         Vaini           0      IN  1550693063        92  15.34  74.49
# 2    Bredasdorp          88      ZA  1550689200        68 -34.53  20.04
# 3     Kungurtug           0      RU  1550692777        45  50.60  97.53
# 4  Ponta do Sol          32      BR  1550693065        77 -20.63 -46.00
#
#    Max Temp  Wind Speed
# 0     48.20        4.70
# 1     64.07        1.70
# 2     69.80        3.36
# 3    -11.67        2.37
# 4     78.20        3.15

# %%
city_df.count()
# Out:
# City          539
# Cloudiness    539
# Country       539
# Date          539
# Humidity      539
# Lat           539
# Lng           539
# Max Temp      539
# Wind Speed    539
# dtype: int64

# %%
city_df.to_csv('cities.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()

ax.scatter(city_df["Lat"], city_df["Max Temp"], color = 'blue', alpha = 0.75, edgecolor = 'black')
ax.grid(linewidth = 0.5)

plt.xlabel("Latitude", Fontsize = 10)
plt.ylabel("Max Temperature (F)", Fontsize = 10)
plt.title("City Latitude vs. Max Temperature (02/20/2019)", Fontsize = 15)

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()

ax.scatter(city_df["Lat"], city_df["Humidity"], color = 'blue', alpha = 0.75, edgecolor = 'black')
ax.grid(linewidth = 0.5)

plt.xlabel("Latitude", Fontsize = 10)
plt.ylabel("Humidity (%)", Fontsize = 10)
plt.title("City Latitude vs. Humidity (02/20/2019)", Fontsize = 15)

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()

ax.scatter(city_df["Lat"], city_df["Cloudiness"], color = 'blue', alpha = 0.75, edgecolor = 'black')
ax.grid(linewidth = 0.5)

plt.xlabel("Latitude", Fontsize = 10)
plt.ylabel("Cloudiness (%)", Fontsize = 10)
plt.title("City Latitude vs. Cloudiness (02/20/2019)", Fontsize = 15)

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()

ax.scatter(city_df["Lat"], city_df["Wind Speed"], color = 'blue', alpha = 0.75, edgecolor = 'black')
ax.grid(linewidth = 0.5)

plt.xlabel("Latitude", Fontsize = 10)
plt.ylabel("Wind Speed (mph)", Fontsize = 10)
plt.title("City Latitude vs. Wind Speed (02/20/2019)", Fontsize = 15)

plt.show()
